# %% [markdown]
# # Evaluation of Stochastic Offering Strategies for Wind Power in Day-Ahead Markets
#
# In this section we will select distinct offers for the day-ahead market and evaluate their performance given real market and wind outcomes over multiple days. The evaluation will be based on the profit obtained from each strategy. For this we will consider the case of a One-Price imbalance settlement market.
#
# Compared strategies will include:
#
# - Optimal stochastic offer for One Price Model considering $\beta = \{0.5, 0.9\} \wedge \alpha = \{0.9, 0.975\}$
# - Optimal stochastic offer optimising for Two Price Model, but evaluated in a One Price Model, considering $\beta = \{0.5, 0.9\} \wedge \alpha = \{0.9, 0.975\}$
# - Offering Pmax in the day-ahead market.
# - Offering the forecasted day ahead wind power output.
# - Offering the expected value of wind power output in the day-ahead market.
